# %% [markdown]
# ### Point Tracking DeepTrack Demo
#
# #### ProcessPointData is the script that trains the DeepTrack LodeSTAR model with the first frame of the video. The model weights can be saved.
#
# #### You only need to train the model once, then simply load the model weights and use it to track the points in all other videos with process_video.py CLI.
#
# #### The notebook contains a demo of how to use the model to track points in a video.

# %%
import os, sys
import cv2
module_path = os.path.abspath(os.path.join(os.path.expanduser('~/NSF_Project/Distraction1/')))
if not module_path in sys.path:
    print("appending path")
    sys.path.append(module_path)

print(sys.path)
import DeepTrackUtils 
from matplotlib import pyplot as plt

 

# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
# Out:
# appending path
# ['/path/to/cloned/directory/CMU-MultimodalSDK', '/home/peter/NSF_Project/Distraction1/Benefit_of_Distraction-master1/get_Dyno/training', '/home/peter/.conda/envs/syndyn/lib/python310.zip', '/home/peter/.conda/envs/syndyn/lib/python3.10', '/home/peter/.conda/envs/syndyn/lib/python3.10/lib-dynload', '', '/home/peter/.local/lib/python3.10/site-packages', '/home/peter/.conda/envs/syndyn/lib/python3.10/site-packages', '/home/peter/NSF_Project/Distraction1']

# %%
import numpy as np

def to_blob_8u(img):
    # Convert to grayscale if needed
    if img.ndim == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Already correct type
    if img.dtype == np.uint8:
        return img.copy()

    # Normalize safely to [0,255] and convert
    img8 = cv2.normalize(
        img, None, 0, 255,
        norm_type=cv2.NORM_MINMAX,
        dtype=cv2.CV_8U
    )
    return img8

# %% [markdown]
# ### Annotate the image with blob detection

# %% [markdown]
# #### 1. We examing the quality of blob detection aftre tuning the parameters:

# %%
video_folder = "/home/peter/DynoNAS/Peter/Research_data/"
video_file_name  = '7_2024y_03m_19d_08h_10m_35s_594ms_614us_tracking_0/2024y_03m_19d_08h_10m_35s_594ms_614us_tracking_0_ground_truth.avi'
video_path  = os.path.join(video_folder, video_file_name)

cap = cv2.VideoCapture(video_path)
i = 0
while cap.isOpened():
    ret, raw_image = cap.read()
    if not ret:
        break
    
    if i == 0 :
        pass
        # plt.figure()
        # plt.imshow(image)
        # plt.show()
    
    if i > 0:
        break
    
    i += 1

cap.release()

image = raw_image
params = cv2.SimpleBlobDetector_Params()
# --- Thresholding (MOST IMPORTANT) ---
params.minThreshold = 50
params.maxThreshold = 220
params.thresholdStep = 10

# --- Color (optional, but strong) ---
params.filterByColor = True
params.blobColor = 255

# --- Area (reject small / large blobs) ---
params.filterByArea = True
params.minArea = 50.0
params.maxArea = 1000.0
params.filterByCircularity = False
params.minCircularity = 0.5
# --- Convexity (reject jagged / fuzzy edges) ---
params.filterByConvexity = True
params.minConvexity = 0.4

# --- Inertia (reject elongated shapes) ---
params.filterByInertia = True
params.minInertiaRatio = 0.2


detector = cv2.SimpleBlobDetector_create(params)
keypoints = detector.detect(image)


# Draw blobs as blue circles
output = cv2.drawKeypoints(image, keypoints, np.array([]), (0, 0, 255),
                           cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
 
# Show the output
plt.figure()
plt.imshow(output)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### 2. Great! The fine tuning works well! Now we exam the bounding box and training data cropping pipeline:
# ##### We want to crop each blob into a patch of fixed size, and save to the training data folder.

# %%
H, W, C = image.shape
patches = []
patch_boxes = []

for i, kp in enumerate(keypoints):
    x, y = kp.pt
    r = kp.size / 2.0 + 4

    # Compute bounds
    x1 = int(np.floor(x - r))
    y1 = int(np.floor(y - r))
    x2 = int(np.ceil (x + r))
    y2 = int(np.ceil (y + r))

    # Clip to image bounds
    x1 = max(0, x1)
    y1 = max(0, y1)
    x2 = min(W, x2)
    y2 = min(H, y2)

    # Crop
    patch = image[y1:y2, x1:x2]

    patches.append(patch)
    patch_boxes.append([x1, y1, x2, y2])


os.makedirs(os.path.expanduser("~/NSF_Project/Distraction1/Benefit_of_Distraction-master1/get_Dyno/training/dot_patches"), exist_ok=True)

for i, patch in enumerate(patches):
    cv2.imwrite(f"dot_patches/dot_{i:03d}.png", patch)

# %% [markdown]
# #### 3. Great! The cropping pipeline for a single image works well! Now we want to apply it to the video.
#
# ##### We combine the loop of cv.VideoCapture with the cropping pipeline.

# %%
def detect_and_crop(image: np.ndarray, keypoints: list, starting_index=0):
    H, W, C = image.shape
    patches = []
    patch_boxes = []

    for i, kp in enumerate(keypoints):
        x, y = kp.pt
        r = kp.size / 2.0 + 4

        # Compute bounds
        x1 = int(np.floor(x - r))
        y1 = int(np.floor(y - r))
        x2 = int(np.ceil (x + r))
        y2 = int(np.ceil (y + r))

        # Clip to image bounds
        x1 = max(0, x1)
        y1 = max(0, y1)
        x2 = min(W, x2)
        y2 = min(H, y2)

        # Crop
        patch = image[y1:y2, x1:x2]

        patches.append(patch)
        patch_boxes.append([x1, y1, x2, y2])


    os.makedirs(os.path.expanduser("~/NSF_Project/Distraction1/Benefit_of_Distraction-master1/get_Dyno/training/dot_patches"), exist_ok=True)

    for i, patch in enumerate(patches):
        cv2.imwrite(f"dot_patches/dot_{ starting_index + i:05d}.png", patch)


cap = cv2.VideoCapture(video_path)
starting_index = 0
while cap.isOpened():
    ret, raw_image = cap.read()
    if not ret:
        break
    
    keypoints = detector.detect(raw_image)
    detect_and_crop(raw_image, keypoints, starting_index)
    starting_index += len(keypoints)
    
    

cap.release()

# %% [markdown]
# ### Train the deeptrack model from data in data folder `/get_Dyno/training/dot_patches`

# %%
import torch
import deeptrack as dt
import deeptrack.deeplay as dl 
import glob
import random
import imageio.v2 as imageio

image_patches_dir = "~/NSF_Project/Distraction1/Benefit_of_Distraction-master1/get_Dyno/training/"
image_files = sorted(glob.glob(os.path.join(os.path.expanduser(image_patches_dir), "dot_patches" + "/*.png")))

dataset = dt.sources.ImageFolder(root=os.path.join(os.path.expanduser(image_patches_dir), "dot_patches"))

test_image = cv2.imread(image_files[100])

print(f"Dataset contains {len(dataset)} images")
# for item in dataset:
#     print(item["path"])
print("Train classes:", dataset.classes)


def sample_image():
    path = random.choice(image_files)
    return imageio.imread(path)

training_pipeline = (
    dt.Value(sample_image)          # load image from disk
    >> dt.Resize((28, 28))                   # enforce fixed size
    >> dt.Gaussian(sigma=lambda:np.random.uniform(0, 0.2))
    >> dt.Multiply(lambda: np.random.uniform(0.6, 1.2))
    >> dt.NormalizeStandard()           # IMPORTANT for LodeSTAR
    >> dt.MoveAxis(-1, 0)                     # HWC → CHW
    >> dt.pytorch.ToTensor(dtype=torch.float32)
)

training_dataset = dt.pytorch.Dataset(training_pipeline, length=400, 
                                      replace=False)

tracker = DeepTrackUtils.DeepTrackTracker(
    n_transforms=4,
    lr=1e-4,
    capacity=500,
    max_distance=10,
)


model, trainer = tracker.train(
    training_dataset,
    batch_size=8,
    max_epochs=200,
)
# Out:
# WARNING:pint.util:Redefining '[magnetic_flux]' (<class 'pint.delegates.txt_defparser.plain.DerivedDimensionDefinition'>)
# Dataset contains 70312 images
# Train classes: ['dot_49042.png', 'dot_29168.png', 'dot_27056.png', 'dot_34338.png', 'dot_30853.png', 'dot_05203.png', 'dot_68040.png', 'dot_22248.png', 'dot_24856.png', 'dot_28422.png', 'dot_20696.png', 'dot_53334.png', 'dot_57897.png', 'dot_54463.png', 'dot_27897.png', 'dot_21183.png', 'dot_09084.png', 'dot_05500.png', 'dot_26965.png', 'dot_37040.png', 'dot_03975.png', 'dot_48124.png', 'dot_05472.png', 'dot_20473.png', 'dot_58515.png', 'dot_20721.png', 'dot_10695.png', 'dot_56624.png', 'dot_62672.png', 'dot_20996.png', 'dot_28390.png', 'dot_00472.png', 'dot_14975.png', 'dot_25002.png', 'dot_13725.png', 'dot_31127.png', 'dot_21340.png', 'dot_35555.png', 'dot_20450.png', 'dot_68240.png', 'dot_46297.png', 'dot_69148.png', 'dot_00668.png', 'dot_20383.png', 'dot_25903.png', 'dot_54226.png', 'dot_56235.png', 'dot_25200.png', 'dot_51944.png', 'dot_48471.png', 'dot_03584.png', 'dot_33429.png', 'dot_55731.png', 'dot_38156.png', 'dot_41029.png', 'dot_39515.png', 'dot_21849.png', 'dot_46555.png', 'dot_46926.png', 'dot_03777.png', 'dot_27815.png', 'dot_67812.png', 'dot_68949.png', 'dot_34176.png', 'dot_52432.png', 'dot_43263.png', 'dot_65886.png', 'dot_61123.png', 'dot_13202.png', 'dot_13013.png', 'dot_23453.png', 'dot_24068.png', 'dot_65562.png', 'dot_68669.png', 'dot_69685.png', 'dot_43472.png', 'dot_40928.png', 'dot_44840.png', 'dot_49762.png', 'dot_62392.png', 'dot_16778.png', 'dot_22693.png', 'dot_12156.png', 'dot_20543.png', 'dot_18298.png', 'dot_34646.png', 'dot_36288.png', 'dot_15154.png', 'dot_60026.png', 'dot_49439.png', 'dot_04493.png', 'dot_14979.png', 'dot_12257.png', 'dot_23344.png', 'dot_18944.png', 'dot_11834.png', 'dot_10660.png', 'dot_52431.png', 'dot_38538.png', 'dot_08341.png', 'dot_16412.png', 'dot_53089.png', 'dot_13750.png', 'dot_29623.png', 'dot_63184.png', 'dot_57118.png', 'dot_46189.png', 'dot_67689.png', 'dot_06837.png', 'dot_36754.png', 'dot_42618.png', 'dot_13112.png', 'dot_01987.png', 'dot_08148.png', 'dot_64255.png', 'dot_68230.png', 'dot_05574.png', 'dot_22833.png', 'dot_38794.png', 'dot_51048.png', 'dot_20279.png', 'dot_31181.png', 'dot_59937.png', 'dot_44132.png', 'dot_46420.png', 'dot_40581.png', 'dot_68998.png', 'dot_06143.png', 'dot_35472.png', 'dot_56569.png', 'dot_35243.png', 'dot_17824.png', 'dot_19119.png', 'dot_31346.png', 'dot_48213.png', 'dot_19526.png', 'dot_29368.png', 'dot_22971.png', 'dot_02678.png', 'dot_48843.png', 'dot_27803.png', 'dot_33018.png', 'dot_65280.png', 'dot_37259.png', 'dot_45174.png', 'dot_35839.png', 'dot_62730.png', 'dot_32774.png', 'dot_67531.png', 'dot_17222.png', 'dot_16929.png', 'dot_16528.png', 'dot_24258.png', 'dot_39763.png', 'dot_49789.png', 'dot_23258.png', 'dot_36205.png', 'dot_57682.png', 'dot_20938.png', 'dot_44245.png', 'dot_31320.png', 'dot_55218.png', 'dot_55886.png', 'dot_17756.png', 'dot_08603.png', 'dot_24135.png', 'dot_26692.png', 'dot_43643.png', 'dot_22631.png', 'dot_46394.png', 'dot_52291.png', 'dot_03569.png', 'dot_05679.png', 'dot_19201.png', 'dot_29840.png', 'dot_35538.png', 'dot_37364.png', 'dot_48670.png', 'dot_20911.png', 'dot_34717.png', 'dot_045.png', 'dot_39878.png', 'dot_32329.png', 'dot_21625.png', 'dot_40886.png', 'dot_05616.png', 'dot_09974.png', 'dot_63646.png', 'dot_46155.png', 'dot_46628.png', 'dot_69941.png', 'dot_19356.png', 'dot_49195.png', 'dot_05576.png', 'dot_36979.png', 'dot_65330.png', 'dot_17492.png', 'dot_19547.png', 'dot_21829.png', 'dot_37393.png', 'dot_37130.png', 'dot_43870.png', 'dot_48736.png', 'dot_65265.png', 'dot_35104.png', 'dot_35605.png', 'dot_69276.png', 'dot_51226.png', 'dot_40589.png', 'dot_55131.png', 'dot_17566.png', 'dot_37533.png', 'dot_05156.png', 'dot_37659.png', 'dot_57636.png', 'dot_59244.png', 'dot_69478.png', 'dot_06289.png', 'dot_67475.png', 'dot_43560.png', 'dot_42566.png', 'dot_23287.png', 'dot_16155.png', 'dot_11542.png', 'dot_25742.png', 'dot_04056.png', 'dot_00464.png', 'dot_62291.png', 'dot_44375.png', 'dot_55397.png', 'dot_59134.png', 'dot_08778.png', 'dot_43125.png', 'dot_17209.png', 'dot_640 ...
# /home/peter/.conda/envs/syndyn/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# /home/peter/.conda/envs/syndyn/lib/python3.10/site-packages/lightning/pytorch/trainer/configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# /home/peter/.conda/envs/syndyn/lib/python3.10/site-packages/lightning/pytorch/utilities/model_summary/model_summary.py:543: The total number of parameters detected may be inaccurate because the model contains an instance of `UninitializedParameter`. To get an accurate number, set `self.example_input_array` in your LightningModule.
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type                       ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model         │ ConvolutionalNeuralNetwork │  251 K │ train │     0 │
# │ 1 │ between_loss  │ L1Loss                     │      0 │ train │     0 │
# │ 2 │ within_loss   │ L1Loss                     │      0 │ train │     0 │
# │ 3 │ train_metrics │ MetricCollection           │      0 │ train │     0 │
# │ 4 │ val_metrics   │ MetricCollection           │      0 │ train │     0 │
# │ 5 │ test_metrics  │ MetricCollection           │      0 │ train │     0 │
# │ 6 │ optimizer     │ Adam                       │      0 │ train │     0 │
# └───┴───────────────┴────────────────────────────┴────────┴───────┴───────┘
# Trainable params: 251 K
# Non-trainable params: 0
# Total params: 251 K
# Total estimated model params size (MB): 1
# Modules in train mode: 39
# Modules in eval mode: 0
# Total FLOPs: 0
# Training: |          | 0/? [00:00<?, ?it/s]

# %%
trainer.history.plot()
# Out:
# (<Figure size 1500x500 with 2 Axes>,
#  array([<Axes: title={'center': 'Between image disagreement'}, xlabel='Step'>,
#         <Axes: title={'center': 'Within image disagreement'}, xlabel='Step'>],
#        dtype=object))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Save weights, load weights, and inference on new data.

# %%
torch.save(model.state_dict(), "./vitrack_tracker_weights.pth")

tracker_test = DeepTrackUtils.DeepTrackTracker()
tracker_test.model.load_state_dict(torch.load("./vitrack_tracker_weights.pth"))
# Out:
# <All keys matched successfully>

# %%
plt.close()
cap = cv2.VideoCapture(video_path)

i =0
while cap.isOpened():
    ret, raw_image = cap.read()
    print("ret:", ret)
    print("cap.isOpened():", cap.isOpened())
    print("type:", type(raw_image))
    print("dtype:", getattr(raw_image, "dtype", None))
    print("shape:", getattr(raw_image, "shape", None))

    # If dtype is object, inspect a few elements' types
    if isinstance(raw_image, np.ndarray) and raw_image.dtype == object:
        flat = raw_image.ravel()
        print("sample element types:", {type(flat[i]) for i in range(min(10, flat.size))})

    if not ret or i == 139:
        print(f"break, i: {i}")
        break
    i += 1
    
cap.release()



# Detect
dets = tracker._detect_frame(raw_image)

H, W, C = raw_image.shape
valid = (
    (dets[:, 0] >= 0) & (dets[:, 0] < H) &
    (dets[:, 1] >= 0) & (dets[:, 1] < W)
)

dets = dets[valid]
plt.figure()
plt.imshow(raw_image)
plt.scatter(dets[:, 1], dets[:, 0], color="r", marker="+")

plt.title("Detections")
plt.show()
# Out:
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# ret: True
# cap.isOpened(): True
# type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (480, 640, 3)
# break, i: 139
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### detect the whole video and save as a .avi file

# %%
tracks = tracker.infer_video(video_path, to_gray=False)
print(video_path)
output_path = "~/NSF_Project/Distraction1/Benefit_of_Distraction-master1/Dyno_Data/" + os.path.basename(video_path).split(".")[0]+ "_DeepTrackTracks.npy"
print(output_path)

np.save(os.path.expanduser(output_path), tracks)
# Out:
# /home/peter/DynoNAS/Peter/Research_data/7_2024y_03m_19d_08h_10m_35s_594ms_614us_tracking_0/2024y_03m_19d_08h_10m_35s_594ms_614us_tracking_0_ground_truth.avi
# ~/NSF_Project/Distraction1/Benefit_of_Distraction-master1/Dyno_Data/2024y_03m_19d_08h_10m_35s_594ms_614us_tracking_0_ground_truth_DeepTrackTracks.npy
